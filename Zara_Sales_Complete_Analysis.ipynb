# %% [markdown]
# # 🛍️ Zara Sales Data Analysis - Complete ML Project with PCA
#
# ## Project Overview
# This notebook demonstrates a complete end-to-end machine learning pipeline:
#
# ### 📋 Contents:
# 1. **Data Loading & Exploration**
# 2. **Data Cleaning & Missing Values Handling**
# 3. **Exploratory Data Analysis (EDA)**
#    - Univariate Analysis
#    - Bivariate Analysis
#    - Multivariate Analysis
# 4. **Feature Engineering**
# 5. **Data Preprocessing**
# 6. **Principal Component Analysis (PCA)**
# 7. **Machine Learning Models**
#    - Linear Regression
#    - Ridge Regression
#    - Random Forest
#    - Gradient Boosting
# 8. **Models with PCA Features**
# 9. **Model Evaluation & Comparison**
# 10. **Predictions & Insights**

# %% [markdown]
# ---
# ## 1️⃣ Import Libraries

# %%
# Data manipulation
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.decomposition import PCA

# Settings
import warnings
warnings.filterwarnings('ignore')
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')
pd.set_option('display.max_columns', None)

print("✅ All libraries imported successfully!")

# %% [markdown]
# ---
# ## 2️⃣ Load Dataset

# %%
# Load data
df = pd.read_csv('Zara_sales_EDA.csv', delimiter=';')

print(f"Dataset Shape: {df.shape}")
print(f"\nColumns: {df.columns.tolist()}")
df.head()

# %% [markdown]
# ---
# ## 3️⃣ Initial Data Exploration

# %%
print("Dataset Information:")
df.info()

# %%
print("Statistical Summary:")
df.describe()

# %% [markdown]
# ---
# ## 4️⃣ Run Complete Analysis
#
# **Note:** The complete analysis script includes all steps. You can run it directly or execute individual sections.

# %%
# Run the complete analysis script
# %run complete_zara_analysis.py

# %% [markdown]
# ---
# ## Summary
#
# This notebook has completed:
# - ✅ Data cleaning and preprocessing
# - ✅ Comprehensive EDA (Univariate & Bivariate)
# - ✅ Feature engineering
# - ✅ Principal Component Analysis (PCA)
# - ✅ Multiple ML models training
# - ✅ Model comparison and evaluation
# - ✅ Visualizations and insights
#
# All visualizations have been saved as PNG files in the current directory.
